# %% [markdown]
# <a href="https://colab.research.google.com/github/JulienChoukroun/Automatic-detection-of-sign-language-gestures/blob/main/Automatic_Signal_Detector_Tasks_7_8_Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![PNS](http://caillau.perso.math.cnrs.fr/logo-pns.png)
# # **<center>Automatic Signal Detector Project</center>**
# <center>CHOUKROUN Julien</center>
#
#
# ---

# %% [markdown]
# # README
#
# Here is the link to all my recessaries repository for this projet containing:
# - Dataset.zip (for CNN)
# - In Dataset/
#   - All the images in A_32, B_32 and C_32
#   - dataset.txt and dataset_suffled.txt
#   - MLP15/ with the model.json and model_weights.h5 for the MLP
#   - CNN10/ with the model.json and model_weights.h5 for the CNN
#   - New images to test my models with Test_A, Test_B, Test_C, TestDroite and TestGauche
#
# https://drive.google.com/drive/folders/1dd6mjXJVhMVy7rdOoddvBopVBKCOe0eI?usp=sharing
#
# \
# To load the OpenCV code there are 2 possibilities:
# - If you have downloaded the OpenCV code in your Google Drive, then execute the "drive.mount" command to import your Google Drive.
# - Else, clone the repository with the "git clone" command.

# %% [markdown]
# 1st possibility: import Google Drive to have acces to the OpenCV code and to the dataset (since task 6).

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2nd possibility: Clone this repository.

# %%
# If not clone, clone it
# %cd /content
# !git clone https://github.com/opencv/opencv/
# %cd opencv/samples/python/
# Out:
# /content
# Cloning into 'opencv'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 289280 (delta 0), reused 0 (delta 0), pack-reused 289279
# Receiving objects: 100% (289280/289280), 477.75 MiB | 21.78 MiB/s, done.
# Resolving deltas: 100% (202195/202195), done.
# Checking out files: 100% (6759/6759), done.
# /content/opencv/samples/python

# %% [markdown]
# ## Seventh Task (Create the neural network)

# %% [markdown]
# ### **Multilayer Perceptron (MLP)**

# %% [markdown]
# A multilayer perceptron (MLP) is a class of artificial neural network (ANN). An MLP consists of at least 3 layers of nodes: an input layer, a hidden layer and an output layer. It is a supervised learning algorithm.
#
# All the neurons of the Multilayer Perceptron are interconnected.
# A layer with all its neurons connected to neurons from other layers is called Fully Connected or Dense.
# A Multilayer Perceptron is thus a network of only fully connected layers, or dense layers.
# There is no (underlying) structure in Multilayer Perceptron.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# The following function will take the dataset file and return two arrays: samples and letters
# The array 'samples' will contain the pixels and the array 'letters' will contains the numbers 0, 1 and 2 corresponding to the letters A, B and C
def load_dataset(dataset_file_path):
    a = np.loadtxt(dataset_file_path, delimiter=',', converters={ 0 : lambda ch : ord(ch)-ord('A') })
    samples, letters = a[:,1:], a[:,0]
    return samples, letters

# %%
samples, letters = load_dataset('/content/drive/MyDrive/Projet_Computer_Vision/Dataset/dataset_suffled.txt')

# %%
# We decide how much of the dataset we will use for training and validation
train_ratio = 0.8 # We take 80% of the dataset for the training and 20% of the dataset for the validation
n_train_samples = int(len(samples) * train_ratio)
x_train, y_train = samples[:n_train_samples], letters[:n_train_samples]
x_val, y_val = samples[n_train_samples:], letters[n_train_samples:]

# %%
# We will use Keras library to build and train the MLP
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils import plot_model

# %%
num_classes = 3 # There are three letters A, B and C in the dataset
epochs = 15

x_train = x_train.astype('float32') # Cast to the float type
x_val = x_val.astype('float32')
x_train /= 255 # Scale the data. Normalize the pixel between 0 and 1 instead of be between 0 and 255
x_val /= 255
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
# Out:
# 2398 train samples
# 600 test samples

# %% [markdown]
# **Model layers**
#
# The simplest model is defined in the Sequential class which is a linear stack of Layers.
# We can create a Sequential model and define all of the layers in the constructor. But a more useful idiom is to create a Sequential model and add our layers in the order of the computation we wish to perform.
#
# The first layer in our model must specify the shape of the input.
# This is the number of input attributes and is defined by the input_shape argument. This argument expects an integer.
#
# Then we define the activation function: softmax, relu, tanh, sigmoid, etc.
#
# Here, we have 2 core Layer types used in the neural networks :
# - Dense: Fully connected layer and the most common type of layer used on multi-layer perceptron models. Dense implements the operation: output = activation(dot(input, kernel) + bias) where activation is the element-wise activation function passed as the activation argument, kernel is a weights matrix created by the layer, and bias is a bias vector created by the layer.
# - Dropout: Apply dropout to the model, setting a fraction of inputs to zero in an effort to reduce over fitting.

# %%
# Model layers
# Create a 'Sequential' model and add a Dense layer as the first layer.
# The model will take as input arrays of shape (None, 1024).  
# Note that after the first layer, we don't need to specify the size of the input anymore.
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(1024,))) # Input layer
# Dropout with probability 20%. Useful to avoid overfitting.
model.add(Dropout(0.2))
# A simple fully connected layer with a 'relu' activation.
model.add(Dense(100, activation='relu')) # Hidden layer
# Dropout with probability 20%. Useful to avoid overfitting.
model.add(Dropout(0.2))
# A simple fully connected output layer with a 'softmax' activation.
model.add(Dense(num_classes, activation='softmax')) # Output layer

# %%
# Architecture of our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               102500
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 112,903
# Trainable params: 112,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot the graph of the model
plot_model(model, to_file='MLP_graph.png')

# %% [markdown]
# **Model compilation**
#
# Once we have defined our model, it needs to be compiled.
# This creates the efficient structures used by the underlying backend in order to efficiently execute our model during training.
# We compile our model using the compile() function and it accepts three important attributes:
# - Model optimizer.
# - Loss function.
# - Metrics.
#
# The optimizer is the search technique used to update weights in our model.
# Some popular gradient descent optimizers:
# - SGD (stochastic gradient descent with support of momentum)
# - RMSprop (adaptive learning rate optimization method proposed by Geoffrey Hinton)
# - Adam (Adaptive Moment Estimation that also uses adaptive learning rates)
#
# The loss function, also called the objective function is the evaluation of the model used by the optimizer to navigate the weight space.  This function is used to compute the error as the difference between the actual output and the predicted output.
# Some common examples include:
# - mse: for mean squared error
# - binary_crossentropy: for binary logarithmic loss (logloss)
# - categorical_crossentropy: for multi-class logarithmic loss (logloss)
#
# Metrics are evaluated by the model during training.
# Only one metric is supported at the moment and that is accuracy.

# %%
# Model compilation
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %% [markdown]
# **Model training**
#
# The model is trained on NumPy arrays using the fit() function.
#
# Epochs is the number of times that the model is exposed to the training dataset.
#
# The fit function also allows for some basic evaluation of the model during training. We can provide a validation_data tuple of (x, y) of data to evaluate.
#
# Fitting the model returns a history object with details and metrics calculated for the model each epoch. This can be used for graphing model performance.

# %%
# Model training
history = model.fit(x_train, y_train,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/15
# 75/75 [==============================] - 2s 11ms/step - loss: 1.0322 - accuracy: 0.5028 - val_loss: 0.2589 - val_accuracy: 0.9583
# Epoch 2/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2880 - accuracy: 0.9188 - val_loss: 0.4922 - val_accuracy: 0.7100
# Epoch 3/15
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1290 - accuracy: 0.9585 - val_loss: 0.0190 - val_accuracy: 0.9917
# Epoch 4/15
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1000 - accuracy: 0.9646 - val_loss: 0.0069 - val_accuracy: 0.9967
# Epoch 5/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0541 - accuracy: 0.9831 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 6/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.0067 - val_accuracy: 0.9967
# Epoch 7/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0396 - accuracy: 0.9867 - val_loss: 5.5784e-04 - val_accuracy: 1.0000
# Epoch 8/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0538 - accuracy: 0.9803 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 9/15
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 6.5333e-04 - val_accuracy: 1.0000
# Epoch 10/15
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 2.4512e-04 - val_accuracy: 1.0000
# Epoch 11/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9911 - val_loss: 2.3159e-04 - val_accuracy: 1.0000
# Epoch 12/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9958 - val_loss: 2.1174e-04 - val_accuracy: 1.0000
# Epoch 13/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9959 - val_loss: 1.5847e-04 - val_accuracy: 1.0000
# Epoch 14/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9946 - val_loss: 3.7184e-04 - val_accuracy: 1.0000
# Epoch 15/15
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9956 - val_loss: 1.0062e-04 - val_accuracy: 1.0000

# %%
# Plot the accuracy and the loss according to the epochs

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label = 'val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label = 'val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# %% [markdown]
# **Model prediction**
#
# Once we have trained our model, we can use it to make predictions on test data or new data.
#
# We will use the model.evaluate() function to calculate the loss and the accuracy values for input data.

# %%
# Model prediction
score = model.evaluate(x_val, y_val, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Validation loss: 0.00010062316141556948
# Validation accuracy: 1.0

# %%
# Save the model and the weights. 
# Because every time we train our model, the initialization is random then we will have different results. 

model_json = model.to_json()
with open("/content/drive/MyDrive/Projet_Computer_Vision/Dataset/MLP15/model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("/content/drive/MyDrive/Projet_Computer_Vision/Dataset/MLP15/model_weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# **Conclusion**
#
# To set the best number of epochs, I have tested with different number of epochs. And I have found that the best is to choose 15 epochs for my training.
#
# Here some examples of training with 5, 15 and 30 epochs:

# %% [markdown]
# ![MLP5.png](data:image/png;base64,...)

# %% [markdown]
# ![MLP15.png](data:image/png;base64,...)

# %% [markdown]
# ![MLP30.png](data:image/png;base64,...)

# %% [markdown]
# So we can see that with 5 epochs, the training is not efficient yet. And with 30 epochs, we overfit the model.

# %% [markdown]
# ### **Convolutional Neural Network (CNN)**

# %% [markdown]
# Fully connected layers are not very efficient for working with images. Convolutional neural networks, on the other hand, are much more suited for this job.
#
# Convolutional neural networks basically take an image as input and apply different transformations that condense all the information.
#
# Thanks to convolutional layers, our neural network is able to detect lines, forms, textures and many things.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.utils import plot_model

# %%
img_height, img_width = 32, 32 # Useful for the first layer for 'input_shape'
batch_size = 32

# %% [markdown]
# We unzip our dataset.

# %%
# !cp /content/drive/MyDrive/Projet_Computer_Vision/Dataset.zip .

# %%
# !unzip Dataset.zip -d dataset
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: dataset/Dataset/A/A_146_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_146_32.jpg
#   inflating: dataset/Dataset/A/A_366_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_366_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_373_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_373_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_3_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_3_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_158_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_158_32.jpg
#   inflating: dataset/Dataset/A/A_81_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_81_32.jpg
#   inflating: dataset/Dataset/A/A_292_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_292_32.jpg
#   inflating: dataset/Dataset/A/A_125_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_125_32.jpg
#   inflating: dataset/Dataset/A/A_392_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_392_32.jpg
#   inflating: dataset/Dataset/A/A_11_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_11_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_189_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_189_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_179_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_179_32.jpg
#   inflating: dataset/Dataset/A/A_259_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_259_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_405_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_405_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_410_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_410_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_104_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_104_32.jpg
#   inflating: dataset/Dataset/A/A_481_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_481_32.jpg
#   inflating: dataset/Dataset/A/A_167_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_167_32.jpg
#   inflating: dataset/Dataset/A/A_38_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_38_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_107_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_107_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_112_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_112_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_228_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_228_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_461_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_461_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_474_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_474_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_116_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_116_32.jpg
#   inflating: dataset/Dataset/A/A_175_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_175_32.jpg
#   inflating: dataset/Dataset/A/A_493_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_493_32.jpg
#   inflating: dataset/Dataset/A/A_49_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_49_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_163_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_163_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_176_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_176_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_108_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_108_32.jpg
#   inflating: dataset/Dataset/A/A_84_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_84_32.jpg
#   inflating: dataset/Dataset/A/A_336_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_336_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_323_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_323_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_120_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_120_32.jpg
#   inflating: dataset/Dataset/A/A_397_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_397_32.jpg
#   inflating: dataset/Dataset/A/A_41_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_41_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_54_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_54_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_297_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_297_32.jpg
#   inflating: dataset/Dataset/A/A_469_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_469_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_143_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_143_32.jpg
#   inflating: dataset/Dataset/A/A_220_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_220_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_235_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_235_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_389_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_389_32.jpg
#   inflating: dataset/Dataset/A/A_289_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_289_32.jpg
#   inflating: dataset/Dataset/A/A_352_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_352_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_347_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_347_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_96_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_96_32.jpg
#   inflating: dataset/Dataset/A/A_496_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_496_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_483_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_483_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_285_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_285_32.jpg
#   inflating: dataset/Dataset/A/A_385_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_385_32.jpg
#   inflating: dataset/Dataset/A/A_25_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_25_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_132_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_132_32.jpg
#   inflating: dataset/Dataset/A/A_30_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_30_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_88_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_88_32.jpg
#   inflating: dataset/Dataset/A/A_418_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_418_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_244_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_244_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_251_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_251_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_151_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_151_32.jpg
#   inflating: dataset/Dataset/A/A_194_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_194_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_181_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_181_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_22_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_22_32.jpg
#   inflating: dataset/Dataset/A/A_115_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_115_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_100_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_100_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_348_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_348_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_8_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_8_32.jpg
#   inflating: dataset/Dataset/A/A_499_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_499_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_231_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_231_32.jpg
#   inflating: dataset/Dataset/A/A_460_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_460_32.jpg
#   inflating: dataset/Dataset/A/A_331_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_331_32.jpg
#   inflating: dataset/Dataset/A/A_186_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_186_32.jpg
#   inflating: dataset/Dataset/A/A_252_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_252_32.jpg
#   inflating: dataset/Dataset/A/A_417_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_417_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_402_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_402_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_403_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_403_32.jpg
#   inflating: dataset/Dataset/A/A_352_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_352_32.jpg
#   inflating: dataset/Dataset/A/A_198_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_198_32.jpg
#   inflating: dataset/Dataset/A/A_41_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_41_32.jpg
#   inflating: dataset/Dataset/A/A_30_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_30_32.jpg
#   inflating: dataset/Dataset/A/A_339_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_339_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_171_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_171_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_164_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_164_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_194_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_194_32.jpg
#   inflating: dataset/Dataset/A/A_323_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_323_32.jpg
#   inflating: dataset/Dataset/A/A_472_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_472_32.jpg
#   inflating: dataset/Dataset/A/A_223_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_223_32.jpg
#   inflating: dataset/Dataset/A/A_340_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_340_32.jpg
#   inflating: dataset/Dataset/A/A_411_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_411_32.jpg
#   inflating: dataset/Dataset/A/A_240_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_240_32.jpg
#   inflating: dataset/Dataset/A/A_473_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_473_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_466_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_466_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_53_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_53_32.jpg
#   inflating: dataset/Dataset/A/A_4_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_4_32.jpg
#   inflating: dataset/Dataset/A/A_439_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_439_32.jpg
#   inflating: dataset/Dataset/A/A_368_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_368_32.jpg
#   inflating: dataset/Dataset/A/A_268_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_268_32.jpg
#   inflating: dataset/Dataset/A/A_444_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_444_32.jpg
#   inflating: dataset/Dataset/A/A_315_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_315_32.jpg
#   inflating: dataset/Dataset/A/A_232_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_232_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_227_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_227_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_215_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_215_32.jpg
#   inflating: dataset/Dataset/A/A_18_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_18_32.jpg
#   inflating: dataset/Dataset/A/A_427_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_427_32.jpg
#   inflating: dataset/Dataset/A/A_376_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_376_32.jpg
#   inflating: dataset/Dataset/A/A_53_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_53_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_46_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_46_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_276_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_276_32.jpg
#   inflating: dataset/Dataset/A/A_65_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_65_32.jpg
#   inflating: dataset/Dataset/A/A_324_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_324_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_331_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_331_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_179_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_179_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_186_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_186_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_193_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_193_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_14_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_14_32.jpg
#   inflating: dataset/Dataset/A/A_207_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_207_32.jpg
#   inflating: dataset/Dataset/A/A_307_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_307_32.jpg
#   inflating: dataset/Dataset/A/A_456_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_456_32.jpg
#   inflating: dataset/Dataset/A/A_256_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_256_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_243_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_243_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_69_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_69_32.jpg
#   inflating: dataset/Dataset/A/A_37_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_37_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_22_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_22_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_264_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_264_32.jpg
#   inflating: dataset/Dataset/A/A_364_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_364_32.jpg
#   inflating: dataset/Dataset/A/A_435_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_435_32.jpg
#   inflating: dataset/Dataset/A/A_484_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_484_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_491_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_491_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_108_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_108_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_340_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_340_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_355_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_355_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_77_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_77_32.jpg
#   inflating: dataset/Dataset/A/A_219_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_219_32.jpg
#   inflating: dataset/Dataset/A/A_319_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_319_32.jpg
#   inflating: dataset/Dataset/A/A_448_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_448_32.jpg
#   inflating: dataset/Dataset/A/A_330_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_330_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_325_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_325_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_342_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_342_32.jpg
#   inflating: dataset/Dataset/A/A_413_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_413_32.jpg
#   inflating: dataset/Dataset/A/A_242_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_242_32.jpg
#   inflating: dataset/Dataset/A/A_178_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_178_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_51_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_51_32.jpg
#   inflating: dataset/Dataset/A/A_6_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_6_32.jpg
#   inflating: dataset/Dataset/A/A_47_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_47_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_52_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_52_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_188_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_188_32.jpg
#   inflating: dataset/Dataset/A/A_32_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_32_32.jpg
#   inflating: dataset/Dataset/A/A_226_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_226_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_233_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_233_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_196_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_196_32.jpg
#   inflating: dataset/Dataset/A/A_321_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_321_32.jpg
#   inflating: dataset/Dataset/A/A_470_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_470_32.jpg
#   inflating: dataset/Dataset/A/A_221_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_221_32.jpg
#   inflating: dataset/Dataset/A/A_109_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_109_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_250_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_250_32.jpg
#   inflating: dataset/Dataset/A/A_354_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_354_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_341_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_341_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_401_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_401_32.jpg
#   inflating: dataset/Dataset/A/A_350_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_350_32.jpg
#   inflating: dataset/Dataset/A/A_23_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_23_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_36_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_36_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_43_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_43_32.jpg
#   inflating: dataset/Dataset/A/A_490_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_490_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_485_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_485_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_242_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_242_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_257_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_257_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_20_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_20_32.jpg
#   inflating: dataset/Dataset/A/A_233_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_233_32.jpg
#   inflating: dataset/Dataset/A/A_462_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_462_32.jpg
#   inflating: dataset/Dataset/A/A_333_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_333_32.jpg
#   inflating: dataset/Dataset/A/A_184_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_184_32.jpg
#   inflating: dataset/Dataset/A/A_192_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_192_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_187_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_187_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_266_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_266_32.jpg
#   inflating: dataset/Dataset/A/A_366_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_366_32.jpg
#   inflating: dataset/Dataset/A/A_437_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_437_32.jpg
#   inflating: dataset/Dataset/A/A_403_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_403_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_416_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_416_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_75_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_75_32.jpg
#   inflating: dataset/Dataset/A/A_16_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_16_32.jpg
#   inflating: dataset/Dataset/A/A_278_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_278_32.jpg
#   inflating: dataset/Dataset/A/A_498_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_498_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_378_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_378_32.jpg
#   inflating: dataset/Dataset/A/A_429_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_429_32.jpg
#   inflating: dataset/Dataset/A/A_101_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_101_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_114_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_114_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_349_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_349_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_205_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_205_32.jpg
#   inflating: dataset/Dataset/A/A_305_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_305_32.jpg
#   inflating: dataset/Dataset/A/A_454_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_454_32.jpg
#   inflating: dataset/Dataset/A/A_425_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_425_32.jpg
#   inflating: dataset/Dataset/A/A_374_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_374_32.jpg
#   inflating: dataset/Dataset/A/A_274_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_274_32.jpg
#   inflating: dataset/Dataset/A/A_458_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_458_32.jpg
#   inflating: dataset/Dataset/A/A_309_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_309_32.jpg
#   inflating: dataset/Dataset/A/A_209_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_209_32.jpg
#   inflating: dataset/Dataset/A/A_67_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_67_32.jpg
#   inflating: dataset/Dataset/A/A_467_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_467_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_472_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_472_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_338_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_338_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_79_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_79_32.jpg
#   inflating: dataset/Dataset/A/A_165_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_165_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_170_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_170_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_446_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_446_32.jpg
#   inflating: dataset/Dataset/A/A_317_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_317_32.jpg
#   inflating: dataset/Dataset/A/A_217_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_217_32.jpg
#   inflating: dataset/Dataset/A/A_177_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_177_32.jpg
#   inflating: dataset/Dataset/A/A_491_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_491_32.jpg
#   inflating: dataset/Dataset/A/A_234_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_234_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_221_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_221_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_468_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_468_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_169_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_169_32.jpg
#   inflating: dataset/Dataset/A/A_55_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_55_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_40_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_40_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_114_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_114_32.jpg
#   inflating: dataset/Dataset/A/A_322_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_322_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_337_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_337_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_180_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_180_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_195_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_195_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_483_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_483_32.jpg
#   inflating: dataset/Dataset/A/A_165_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_165_32.jpg
#   inflating: dataset/Dataset/A/A_250_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_250_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_245_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_245_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_419_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_419_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_118_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_118_32.jpg
#   inflating: dataset/Dataset/A/A_482_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_482_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_497_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_497_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_31_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_31_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_24_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_24_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_346_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_346_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_353_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_353_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_106_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_106_32.jpg
#   inflating: dataset/Dataset/A/A_153_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_153_32.jpg
#   inflating: dataset/Dataset/A/A_113_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_113_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_106_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_106_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_299_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_299_32.jpg
#   inflating: dataset/Dataset/A/A_39_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_39_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_399_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_399_32.jpg
#   inflating: dataset/Dataset/A/A_411_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_411_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_404_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_404_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_94_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_94_32.jpg
#   inflating: dataset/Dataset/A/A_258_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_258_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_287_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_287_32.jpg
#   inflating: dataset/Dataset/A/A_188_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_188_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_387_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_387_32.jpg
#   inflating: dataset/Dataset/A/A_130_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_130_32.jpg
#   inflating: dataset/Dataset/A/A_141_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_141_32.jpg
#   inflating: dataset/Dataset/A/A_98_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_98_32.jpg
#   inflating: dataset/Dataset/A/A_177_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_177_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_162_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_162_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_48_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_48_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_86_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_86_32.jpg
#   inflating: dataset/Dataset/A/A_475_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_475_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_460_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_460_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_229_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_229_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_122_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_122_32.jpg
#   inflating: dataset/Dataset/A/A_395_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_395_32.jpg
#   inflating: dataset/Dataset/A/A_295_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_295_32.jpg
#   inflating: dataset/Dataset/A/A_119_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_119_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_344_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_344_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_351_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_351_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_63_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_63_32.jpg
#   inflating: dataset/Dataset/A/A_370_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_370_32.jpg
#   inflating: dataset/Dataset/A/A_421_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_421_32.jpg
#   inflating: dataset/Dataset/A/A_270_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_270_32.jpg
#   inflating: dataset/Dataset/A/A_33_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_33_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_26_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_26_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_480_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_480_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_495_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_495_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_252_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_252_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_247_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_247_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_313_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_313_32.jpg
#   inflating: dataset/Dataset/A/A_442_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_442_32.jpg
#   inflating: dataset/Dataset/A/A_213_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_213_32.jpg
#   inflating: dataset/Dataset/A/A_182_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_182_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_197_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_197_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_320_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_320_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_335_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_335_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_168_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_168_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_71_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_71_32.jpg
#   inflating: dataset/Dataset/A/A_262_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_262_32.jpg
#   inflating: dataset/Dataset/A/A_433_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_433_32.jpg
#   inflating: dataset/Dataset/A/A_362_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_362_32.jpg
#   inflating: dataset/Dataset/A/A_57_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_57_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_42_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_42_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_236_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_236_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_223_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_223_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_201_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_201_32.jpg
#   inflating: dataset/Dataset/A/A_450_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_450_32.jpg
#   inflating: dataset/Dataset/A/A_301_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_301_32.jpg
#   inflating: dataset/Dataset/A/A_12_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_12_32.jpg
#   inflating: dataset/Dataset/A/A_47_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_47_32.jpg
#   inflating: dataset/Dataset/A/A_229_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_229_32.jpg
#   inflating: dataset/Dataset/A/A_329_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_329_32.jpg
#   inflating: dataset/Dataset/A/A_478_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_478_32.jpg
#   inflating: dataset/Dataset/A/A_477_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_477_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_462_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_462_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_254_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_254_32.jpg
#   inflating: dataset/Dataset/A/A_354_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_354_32.jpg
#   inflating: dataset/Dataset/A/A_405_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_405_32.jpg
#   inflating: dataset/Dataset/A/A_237_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_237_32.jpg
#   inflating: dataset/Dataset/A/A_337_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_337_32.jpg
#   inflating: dataset/Dataset/A/A_466_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_466_32.jpg
#   inflating: dataset/Dataset/A/A_180_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_180_32.jpg
#   inflating: dataset/Dataset/A/A_59_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_59_32.jpg
#   inflating: dataset/Dataset/A/A_328_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_328_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_175_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_175_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_160_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_160_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_24_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_24_32.jpg
#   inflating: dataset/Dataset/A/A_55_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_55_32.jpg
#   inflating: dataset/Dataset/A/A_2_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_2_32.jpg
#   inflating: dataset/Dataset/A/A_413_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_413_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_406_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_406_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_28_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_28_32.jpg
#   inflating: dataset/Dataset/A/A_417_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_417_32.jpg
#   inflating: dataset/Dataset/A/A_346_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_346_32.jpg
#   inflating: dataset/Dataset/A/A_246_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_246_32.jpg
#   inflating: dataset/Dataset/A/A_192_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_192_32.jpg
#   inflating: dataset/Dataset/A/A_474_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_474_32.jpg
#   inflating: dataset/Dataset/A/A_325_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_325_32.jpg
#   inflating: dataset/Dataset/A/A_488_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_488_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_225_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_225_32.jpg
#   inflating: dataset/Dataset/A/A_409_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_409_32.jpg
#   inflating: dataset/Dataset/A/A_358_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_358_32.jpg
#   inflating: dataset/Dataset/A/A_258_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_258_32.jpg
#   inflating: dataset/Dataset/A/A_111_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_111_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_104_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_104_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_36_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_36_32.jpg
#   inflating: dataset/Dataset/A/A_359_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_359_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_138_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_138_32.jpg
#   inflating: dataset/Dataset/A/A_190_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_190_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_185_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_185_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_145_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_145_32.jpg
#   inflating: dataset/Dataset/A/A_409_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_409_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_240_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_240_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_255_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_255_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_492_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_492_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_487_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_487_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_21_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_21_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_34_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_34_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_126_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_126_32.jpg
#   inflating: dataset/Dataset/A/A_391_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_391_32.jpg
#   inflating: dataset/Dataset/A/A_291_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_291_32.jpg
#   inflating: dataset/Dataset/A/A_82_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_82_32.jpg
#   inflating: dataset/Dataset/A/A_356_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_356_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_343_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_343_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_478_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_478_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_157_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_157_32.jpg
#   inflating: dataset/Dataset/A/A_224_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_224_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_231_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_231_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_45_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_45_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_50_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_50_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_283_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_283_32.jpg
#   inflating: dataset/Dataset/A/A_383_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_383_32.jpg
#   inflating: dataset/Dataset/A/A_134_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_134_32.jpg
#   inflating: dataset/Dataset/A/A_90_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_90_32.jpg
#   inflating: dataset/Dataset/A/A_149_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_149_32.jpg
#   inflating: dataset/Dataset/A/A_332_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_332_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_327_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_327_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_167_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_167_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_172_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_172_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_58_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_58_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_487_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_487_32.jpg
#   inflating: dataset/Dataset/A/A_161_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_161_32.jpg
#   inflating: dataset/Dataset/A/A_102_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_102_32.jpg
#   inflating: dataset/Dataset/A/A_239_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_239_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_465_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_465_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_470_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_470_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_499_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_499_32.jpg
#   inflating: dataset/Dataset/A/A_103_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_103_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_116_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_116_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_173_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_173_32.jpg
#   inflating: dataset/Dataset/A/A_495_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_495_32.jpg
#   inflating: dataset/Dataset/A/A_29_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_29_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_248_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_248_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_110_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_110_32.jpg
#   inflating: dataset/Dataset/A/A_401_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_401_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_414_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_414_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_198_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_198_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_281_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_281_32.jpg
#   inflating: dataset/Dataset/A/A_381_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_381_32.jpg
#   inflating: dataset/Dataset/A/A_136_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_136_32.jpg
#   inflating: dataset/Dataset/A/A_471_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_471_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_464_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_464_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_238_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_238_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_92_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_92_32.jpg
#   inflating: dataset/Dataset/A/A_59_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_59_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_128_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_128_32.jpg
#   inflating: dataset/Dataset/A/A_173_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_173_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_166_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_166_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_155_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_155_32.jpg
#   inflating: dataset/Dataset/A/A_124_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_124_32.jpg
#   inflating: dataset/Dataset/A/A_393_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_393_32.jpg
#   inflating: dataset/Dataset/A/A_293_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_293_32.jpg
#   inflating: dataset/Dataset/A/A_199_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_199_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_159_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_159_32.jpg
#   inflating: dataset/Dataset/A/A_415_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_415_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_400_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_400_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_249_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_249_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_80_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_80_32.jpg
#   inflating: dataset/Dataset/A/A_28_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_28_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_147_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_147_32.jpg
#   inflating: dataset/Dataset/A/A_117_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_117_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_102_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_102_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_342_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_342_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_357_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_357_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_112_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_112_32.jpg
#   inflating: dataset/Dataset/A/A_486_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_486_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_493_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_493_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_489_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_489_32.jpg
#   inflating: dataset/Dataset/A/A_35_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_35_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_20_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_20_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_254_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_254_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_241_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_241_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_408_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_408_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_184_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_184_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_191_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_191_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_171_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_171_32.jpg
#   inflating: dataset/Dataset/A/A_497_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_497_32.jpg
#   inflating: dataset/Dataset/A/A_326_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_326_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_333_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_333_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_100_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_100_32.jpg
#   inflating: dataset/Dataset/A/A_51_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_51_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_44_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_44_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_230_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_230_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_225_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_225_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_479_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_479_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_485_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_485_32.jpg
#   inflating: dataset/Dataset/A/A_163_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_163_32.jpg
#   inflating: dataset/Dataset/A/A_329_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_329_32_flipped.jpg
#   inflating: dataset/Dataset/A/A_203_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_203_32.jpg
#   inflating: dataset/Dataset/A/A_452_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_452_32.jpg
#   inflating: dataset/Dataset/A/A_303_32.jpg
#   inflating: dataset/__MACOSX/Dataset/A/._A_303_32.jpg
# ...
#   inflating: dataset/Dataset/B/B_375_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_375_32.jpg
#   inflating: dataset/Dataset/B/B_424_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_424_32.jpg
#   inflating: dataset/Dataset/B/B_48_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_48_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_455_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_455_32.jpg
#   inflating: dataset/Dataset/B/B_304_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_304_32.jpg
#   inflating: dataset/Dataset/B/B_204_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_204_32.jpg
#   inflating: dataset/Dataset/B/B_102_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_102_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_117_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_117_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_428_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_428_32.jpg
#   inflating: dataset/Dataset/B/B_379_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_379_32.jpg
#   inflating: dataset/Dataset/B/B_279_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_279_32.jpg
#   inflating: dataset/Dataset/B/B_199_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_199_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_85_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_85_32.jpg
#   inflating: dataset/Dataset/B/B_249_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_249_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_400_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_400_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_415_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_415_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_436_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_436_32.jpg
#   inflating: dataset/Dataset/B/B_367_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_367_32.jpg
#   inflating: dataset/Dataset/B/B_267_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_267_32.jpg
#   inflating: dataset/Dataset/B/B_470_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_470_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_465_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_465_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_239_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_239_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_241_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_241_32.jpg
#   inflating: dataset/Dataset/B/B_410_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_410_32.jpg
#   inflating: dataset/Dataset/B/B_341_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_341_32.jpg
#   inflating: dataset/Dataset/B/B_0_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_0_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_222_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_222_32.jpg
#   inflating: dataset/Dataset/B/B_195_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_195_32.jpg
#   inflating: dataset/Dataset/B/B_473_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_473_32.jpg
#   inflating: dataset/Dataset/B/B_322_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_322_32.jpg
#   inflating: dataset/Dataset/B/B_172_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_172_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_167_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_167_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_38_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_38_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_414_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_414_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_401_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_401_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_199_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_199_32.jpg
#   inflating: dataset/Dataset/B/B_248_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_248_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_353_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_353_32.jpg
#   inflating: dataset/Dataset/B/B_402_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_402_32.jpg
#   inflating: dataset/Dataset/B/B_198_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_198_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_253_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_253_32.jpg
#   inflating: dataset/Dataset/B/B_330_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_330_32.jpg
#   inflating: dataset/Dataset/B/B_461_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_461_32.jpg
#   inflating: dataset/Dataset/B/B_187_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_187_32.jpg
#   inflating: dataset/Dataset/B/B_3_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_3_32.jpg
#   inflating: dataset/Dataset/B/B_230_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_230_32.jpg
#   inflating: dataset/Dataset/B/B_116_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_116_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_103_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_103_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_49_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_49_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_449_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_449_32.jpg
#   inflating: dataset/Dataset/B/B_318_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_318_32.jpg
#   inflating: dataset/Dataset/B/B_41_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_41_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_54_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_54_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_218_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_218_32.jpg
#   inflating: dataset/Dataset/B/B_487_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_487_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_87_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_87_32.jpg
#   inflating: dataset/Dataset/B/B_492_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_492_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_434_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_434_32.jpg
#   inflating: dataset/Dataset/B/B_365_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_365_32.jpg
#   inflating: dataset/Dataset/B/B_265_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_265_32.jpg
#   inflating: dataset/Dataset/B/B_343_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_343_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_356_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_356_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_99_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_99_32.jpg
#   inflating: dataset/Dataset/B/B_185_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_185_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_190_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_190_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_457_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_457_32.jpg
#   inflating: dataset/Dataset/B/B_306_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_306_32.jpg
#   inflating: dataset/Dataset/B/B_206_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_206_32.jpg
#   inflating: dataset/Dataset/B/B_255_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_255_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_240_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_240_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_409_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_409_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_25_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_25_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_30_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_30_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_95_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_95_32.jpg
#   inflating: dataset/Dataset/B/B_277_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_277_32.jpg
#   inflating: dataset/Dataset/B/B_327_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_327_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_332_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_332_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_377_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_377_32.jpg
#   inflating: dataset/Dataset/B/B_426_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_426_32.jpg
#   inflating: dataset/Dataset/B/B_8_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_8_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_214_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_214_32.jpg
#   inflating: dataset/Dataset/B/B_314_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_314_32.jpg
#   inflating: dataset/Dataset/B/B_445_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_445_32.jpg
#   inflating: dataset/Dataset/B/B_231_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_231_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_224_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_224_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_269_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_269_32.jpg
#   inflating: dataset/Dataset/B/B_369_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_369_32.jpg
#   inflating: dataset/Dataset/B/B_438_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_438_32.jpg
#   inflating: dataset/Dataset/B/B_478_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_478_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_21_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_21_32.jpg
#   inflating: dataset/Dataset/B/B_109_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_109_32.jpg
#   inflating: dataset/Dataset/B/B_160_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_160_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_175_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_175_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_328_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_328_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_174_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_174_32.jpg
#   inflating: dataset/Dataset/B/B_492_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_492_32.jpg
#   inflating: dataset/Dataset/B/B_7_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_7_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_117_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_117_32.jpg
#   inflating: dataset/Dataset/B/B_462_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_462_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_477_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_477_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_42_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_42_32.jpg
#   inflating: dataset/Dataset/B/B_33_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_33_32.jpg
#   inflating: dataset/Dataset/B/B_488_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_488_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_359_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_359_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_104_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_104_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_111_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_111_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_480_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_480_32.jpg
#   inflating: dataset/Dataset/B/B_166_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_166_32.jpg
#   inflating: dataset/Dataset/B/B_105_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_105_32.jpg
#   inflating: dataset/Dataset/B/B_178_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_178_32.jpg
#   inflating: dataset/Dataset/B/B_50_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_50_32.jpg
#   inflating: dataset/Dataset/B/B_406_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_406_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_413_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_413_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_247_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_247_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_252_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_252_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_150_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_150_32.jpg
#   inflating: dataset/Dataset/B/B_197_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_197_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_182_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_182_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_78_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_78_32.jpg
#   inflating: dataset/Dataset/B/B_351_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_351_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_384_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_384_32.jpg
#   inflating: dataset/Dataset/B/B_344_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_344_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_133_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_133_32.jpg
#   inflating: dataset/Dataset/B/B_284_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_284_32.jpg
#   inflating: dataset/Dataset/B/B_119_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_119_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_495_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_495_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_480_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_480_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_66_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_66_32.jpg
#   inflating: dataset/Dataset/B/B_53_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_53_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_46_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_46_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_288_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_288_32.jpg
#   inflating: dataset/Dataset/B/B_388_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_388_32.jpg
#   inflating: dataset/Dataset/B/B_17_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_17_32.jpg
#   inflating: dataset/Dataset/B/B_223_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_223_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_236_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_236_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_142_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_142_32.jpg
#   inflating: dataset/Dataset/B/B_168_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_168_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_296_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_296_32.jpg
#   inflating: dataset/Dataset/B/B_335_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_335_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_121_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_121_32.jpg
#   inflating: dataset/Dataset/B/B_320_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_320_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_396_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_396_32.jpg
#   inflating: dataset/Dataset/B/B_74_32.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_74_32.jpg
#   inflating: dataset/Dataset/B/B_37_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_37_32_flipped.jpg
#   inflating: dataset/Dataset/B/B_22_32_flipped.jpg
#   inflating: dataset/__MACOSX/Dataset/B/._B_22_32_flipped.jpg

# %% [markdown]
# **Preparing the data for our model**
#
# We decide how much of the dataset we will use for training and validation.

# %%
# Generates a tf.data.Dataset from image files in a directory.

# seed: random seed for shuffling and transformations.

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  './dataset/Dataset',
  validation_split=0.2,
  subset="training",
  color_mode='grayscale',
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3000 files belonging to 3 classes.
# Using 2400 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  './dataset/Dataset',
  validation_split=0.2,
  subset="validation",
  color_mode='grayscale',
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3000 files belonging to 3 classes.
# Using 600 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['A', 'B', 'C']

# %% [markdown]
# **Configure the dataset for performance**
#
# Use buffered prefetching to load images from disk without having I/O become blocking.
#
# Prefetching overlaps the preprocessing and model execution of a training step. While the model is executing training step s, the input pipeline is reading the data for step s+1.
# Doing so reduces the step time to the maximum of the training and the time it takes to extract the data.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Show some images from the train dataset with the labels corresponding.
# To verify that the dataset looks correct, let's plot the first 16 images from the training set and display the class name above each image.
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))
for images, labels in train_ds.take(1):
  for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8").squeeze(), cmap=plt.cm.binary)
    plt.title(class_names[labels[i]])
    plt.axis("off")
  break

# %% [markdown]
# **Model layers**
#
# The simplest model is defined in the Sequential class which is a linear stack of Layers. We can create a Sequential model and define all of the layers in the constructor.
#
# The first layer in our model must specify the shape of the input. This is the number of input attributes and is defined by the input_shape argument. This argument expects an integer.
#
# The convolutionnal layers convolves an image by a matrix, called Kerner or filter. The proccess is as follows:
# - First, we overlay the kernel onto the image.
# - Then we multiply the kernel value by the image value.
# - After that, we calculate the product of the results of the previous step.
# - Finally, we move the kernel one pixel and repeat the process.
#
# Once we have the result from the previous step, we will do as we do on fully connected layers: we add the bias parameter and then apply an activation function (softmax, relu, tanh, sigmoid, etc.).
#
# Despite there is not "one size fits all" Kernel, neural networks with more layers and smaller kernels are more efficient that neural networks with less layers and bigger Kernels. In fact, most kernels have a dimension of 3 by 3. This is the second parameter in the Conv2D function.
#
# With every convolutional layer the size of the result is smaller than the input of the layer. Thus, if we just apply convolutional layers with no other changes, there is a maximum amount of layers that we can apply.
# Anyway, we can add a padding to the image so that the result of the image does not reduce in size.
# The padding basically consists of adding some pixels on the borders of the image before applying the convolution. By doing so, we can get a result that has the same size as the input (without the padding).
#
# The width and height dimensions tend to shrink as you go deeper in the network. The number of output channels for each Conv2D layer is controlled by the first argument (e.g., 32 or 64 or 128). Typically, as the width and height shrink, we can afford (computationally) to add more output channels in each Conv2D layer.
#
# Pooling layers allow us to reduce the size of the image so that the neural network works faster. It basically creates a smaller image by dividing the image in several n by n matrices (2 by 2 matrices here). In Max Pooling layers, the result will be the maximum value of each smaller matrix.
# By applying a max pooling layer we ensure that the shapes detected by the convolutional layer are maintained for the next layer.
#
# Dense: Fully connected layer and the most common type of layer used on multi-layer perceptron models. Dense implements the operation: output = activation(dot(input, kernel) + bias) where activation is the element-wise activation function passed as the activation argument, kernel is a weights matrix created by the layer, and bias is a bias vector created by the layer.
#
# Dropout: Apply dropout to the model, setting a fraction of inputs to zero in an effort to reduce over fitting.

# %%
# Model layers
model = Sequential([
    # 32 convolutional filters of size 3 x 3, 'relu activation', padding = same (https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 1), padding='same'),
    # 2 X 2 max pooling layer (https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D)
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    # Dropout with probability 20%. Useful to avoid overfitting. (https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout)
    layers.Dropout(0.2),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    # Flatten the last image features before liking to a FFN (https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D)
    layers.GlobalAvgPool2D(),
    # A simple fully connected layer with a 'relu' activation
    layers.Dense(64, activation='relu'),
    # A simple fully connected output layer with no activation
    layers.Dense(3)
])

# %%
# Architecture of our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 138,051
# Trainable params: 138,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot the graph of the model
plot_model(model, to_file='CNN_graph.png')

# %% [markdown]
# **Model compilation**
#
# Once we have defined our model, it needs to be compiled.
# This creates the efficient structures used by the underlying backend in order to efficiently execute our model during training.
# We compile our model using the compile() function and it accepts three important attributes:
# - Model optimizer.
# - Loss function.
# - Metrics.
#
# The optimizer is the search technique used to update weights in our model.
# Some popular gradient descent optimizers:
# - SGD (stochastic gradient descent with support of momentum)
# - RMSprop (adaptive learning rate optimization method proposed by Geoffrey Hinton)
# - Adam (Adaptive Moment Estimation that also uses adaptive learning rates)
#
# The loss function, also called the objective function is the evaluation of the model used by the optimizer to navigate the weight space. This function is used to compute the error as the difference between the actual output and the predicted output.
# Some common examples include:
# - mse: for mean squared error
# - binary_crossentropy: for binary logarithmic loss (logloss)
# - categorical_crossentropy: for multi-class logarithmic loss (logloss)
# - tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True): computes the crossentropy loss between the labels and predictions. Using from_logits=True may be more numerically stable.
#
# Metrics are evaluated by the model during training.
# Only one metric is supported at the moment and that is accuracy.

# %%
# Model compilation
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# **Model training**
#
# The model is trained on NumPy arrays using the fit() function.
#
# Epochs is the number of times that the model is exposed to the training dataset.
#
# Batch_size is the number of samples that will be propagated through the network.
#
# The fit function also allows for some basic evaluation of the model during training. We can provide a validation_data tuple of (x, y) of data to evaluate.
#
# Fitting the model returns a history object with details and metrics calculated for the model each epoch. This can be used for graphing model performance.

# %%
# Model training
history = model.fit(train_ds, 
                    epochs=10, 
                    validation_data=val_ds)
# Out:
# Epoch 1/10
# 75/75 [==============================] - 4s 23ms/step - loss: 4.9415 - accuracy: 0.4142 - val_loss: 0.2511 - val_accuracy: 0.9217
# Epoch 2/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.1694 - accuracy: 0.9514 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 3/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0115 - accuracy: 0.9989 - val_loss: 2.6533e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0024 - accuracy: 0.9999 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 5/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 3.3301e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 4.6236e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 7.0613e-05 - val_accuracy: 1.0000
# Epoch 8/10
# 75/75 [==============================] - 1s 10ms/step - loss: 7.9058e-04 - accuracy: 1.0000 - val_loss: 9.4516e-06 - val_accuracy: 1.0000
# Epoch 9/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.5323e-04 - accuracy: 1.0000 - val_loss: 4.4390e-06 - val_accuracy: 1.0000
# Epoch 10/10
# 75/75 [==============================] - 1s 10ms/step - loss: 4.4526e-04 - accuracy: 1.0000 - val_loss: 1.7752e-06 - val_accuracy: 1.0000

# %%
# Plot the accuracy and the loss according to the epochs

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label = 'val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label = 'val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# %% [markdown]
# Once we have trained our model, we can use it to make predictions on test data or new data.
#
# We will use the model.evaluate() function to calculate the loss values for and the accuracy input data.

# %%
# Model prediction
score = model.evaluate(val_ds, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Validation loss: 1.775233954504074e-06
# Validation accuracy: 1.0

# %%
# Save the model and the weights. 
# Because every time we train our model, the initialization is random then we will have different results. 

model_json = model.to_json()
with open("/content/drive/MyDrive/Projet_Computer_Vision/Dataset/CNN10/model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("/content/drive/MyDrive/Projet_Computer_Vision/Dataset/CNN10/model_weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# **Conclusion**
#
# To set the best number of epochs, I have tested with different number of epochs. And I have found that the best is to choose 10 epochs for my training.
#
# Here some examples of training with 5, 10 and 20 epochs:

# %% [markdown]
# ![CNN5.png](data:image/png;base64,...)

# %% [markdown]
# ![CNN10.png](data:image/png;base64,...)

# %% [markdown]
# ![CNN20.png](data:image/png;base64,...)

# %% [markdown]
# So we can see that with 5 epochs, the training is almost efficient. And with 20 epochs, we overfit the model.

# %% [markdown]
# ## Eighth Task (Test phase)

# %%
from keras.models import model_from_json

# We load the model
# Load json and create model
json_file = open('/content/drive/MyDrive/Projet_Computer_Vision/Dataset/CNN10/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# Load weights into new model
loaded_model.load_weights("/content/drive/MyDrive/Projet_Computer_Vision/Dataset/CNN10/model_weights.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %% [markdown]
# To verify that the MLP model loaded correctly, run the next 2 blocks.
# We must have the same loss and accuracy as in the task 7.

# %%
# Model compilation
loaded_model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Model prediction
score_loaded = loaded_model.evaluate(x_val, y_val, verbose=0)
print('Validation loss:', score_loaded[0])
print('Validation accuracy:', score_loaded[1])
# Out:
# Validation loss: 0.00010062316141556948
# Validation accuracy: 1.0

# %% [markdown]
# To verify that the CNN model loaded correctly, run the next 2 blocks.
# We must have the same loss and accuracy as in the task 7.

# %%
# Model compilation
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Model prediction
score = model.evaluate(val_ds, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Validation loss: 1.775233954504074e-06
# Validation accuracy: 1.0

# %% [markdown]
# **Generate new images to predict the letter (from the code from the task 6)**

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode, b64encode

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import io
from google.colab.patches import cv2_imshow
import cv2 # OpenCV library

# %%
# Create a real time video stream
def VideoCapture():
  js = Javascript('''
    async function create(){
      div = document.createElement('div');
      document.body.appendChild(div);

      video = document.createElement('video');
      video.setAttribute('playsinline', '');

      div.appendChild(video);
      stream = await navigator.mediaDevices.getUserMedia({video: {facingMode: "environment"}});
      video.srcObject = stream;

      await video.play();

      canvas =  document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);

      div_out = document.createElement('div');
      document.body.appendChild(div_out);
      img = document.createElement('img');
      div_out.appendChild(img);
    }

    async function capture(){
        return await new Promise(function(resolve, reject){
            pendingResolve = resolve;
            canvas.getContext('2d').drawImage(video, 0, 0);
            result = canvas.toDataURL('image/jpeg', 0.20);

            pendingResolve(result);
        })
    }

    function showimg(imgb64){
        img.src = "data:image/jpg;base64," + imgb64;
    }

  ''')
  display(js)

# %%
# Format transformation
def b64_to_bytes(byte):
  jpeg = b64decode(byte.split(',')[1])
  im = Image.open(io.BytesIO(jpeg))
  return np.array(im)

def bytes_to_b64(image):
  image = Image.fromarray(image)
  buffer = io.BytesIO()
  image.save(buffer, 'jpeg')
  buffer.seek(0)
  x = b64encode(buffer.read()).decode('utf-8')
  return x

# %%
# This function scales a rotated rectangle by a factor of scale_x (width) and scale_y (height)
def scale_contour(pts, scale_x, scale_y):
    M = cv2.moments(pts)

    if M['m00'] == 0:
      return pts

    cx = int(M['m10']/M['m00'])
    cy = int(M['m01']/M['m00'])

    cnt_norm = pts - [cx, cy]
    cnt_scaled = cnt_norm * np.array([scale_x, scale_y])
    cnt_scaled = cnt_scaled + [cx, cy]
    cnt_scaled = cnt_scaled.astype(np.int32)

    return cnt_scaled

# This function crop the hand
# Here we don't retrieve directly the rotated box because it might change the letter. 
# So we compute first a new non rotated bbox, and use it to crop the hand.
def crop_hand(pts, im_width, im_height):
    x_tl, y_tl = max(0, min(pts[:, 0])), max(0, min(pts[:, 1])) # We have the different corners of the rotated bounding box
    x_br, y_br = min(im_width, max(pts[:, 0])), max(im_height, max(pts[:, 1])) # We compute those of the non rotated one arround
    return (x_tl, y_tl), (x_br, y_br)

# %% [markdown]
# If you have loaded your Google Drive, then execute this box but not the next box.

# %%
# Load the cascade classifier
# ! Be careful for the path. You have to change the path with the path of your Google Drive !
faces_cascades = cv2.CascadeClassifier("/content/drive/MyDrive/Projet_Computer_Vision/opencv-master/data/haarcascades/haarcascade_frontalface_alt.xml")

# %% [markdown]
# If you have cloned the repository, then execute this box.

# %%
# Load the cascade classifier
faces_cascades = cv2.CascadeClassifier("/content/opencv/data/haarcascades/haarcascade_frontalface_alt.xml")

# %%
# Detect faces using cascades
# Detect the face in the image
# Detects objects of different sizes in the input image
# The detected objects are returned as a list of rectangles

# In detectMultiScale, the second parameter is the scaleFactor: how much the image size is reduced at each image scale
# And the last parameter is the minNeighbors: how many neighbors each candidate rectangle should have to retain it
def detect_faces(img, cascades):
  # Convert the image into gray scale
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  # Use cascades to detect faces
  faces = cascades.detectMultiScale(gray, 1.3, 4)
  return faces

# %%
# Capture a frame used for histogramm backprojection
VideoCapture()
eval_js('create()')

while True:
  response = input("Type anything when ready!:")
  byte = eval_js('capture()') # Take a capture
  im = b64_to_bytes(byte) # Transform the capture from base64 to an array
  im_copy = im.copy()
  faces = detect_faces(im, faces_cascades) # Detect faces

  if len(faces) == 1: # If the algorithm detects a face
    face = faces[0]
    # Draw a green rectangle around the detected face in the image
    cv2.rectangle(im_copy,(face[0],face[1]),(face[0] + face[2], face[1] + face[3]),(0,255,0),2)
  else:
    continue

  eval_js('showimg("{}")'.format(bytes_to_b64(im_copy))) # We convert our image with bounding boxes to base64 and plot it using JS 
  response = input("Use this bounding box? [y or n]:")
  if response == 'y': # Take a screen shot
    frame = im[face[1]:face[1]+face[3], face[0]:face[0]+face[2]]
    eval_js('showimg("{}")'.format(bytes_to_b64(frame)))
    tracking_window_face = face # Initial tracking window for the face
    break
# Out:
# Type anything when ready!:ok
# Use this bounding box? [y or n]:y

# %%
# Compute the histogram

# Transform the frame into HSV
frameHSV = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
# Create an inRange mask for pixels. Limit the saturation in [64., 255.] and brightness in [32., 200.]
mask = cv2.inRange(frameHSV, np.array((8., 64., 32.)), np.array((180., 255., 200.)))
# Compute the histogram of the frame (use only the HUE channel). See `https://bit.ly/3pdVUEd`
# Take into account only pixels which are not too bright and not too dark (use the previous mask)
# Use 16 bins and specify the range of the hue ([0, 180])
frameHist = cv2.calcHist([frameHSV], [0], mask, [16], [0, 180])
# Normalize the histogram between 0 (lowest intensity) and 255 (highest intensity) (use MinMax normalization `cv.NORM_MINMAX`) using the method `https://bit.ly/3jMGhCj`
frameHist = cv2.normalize(frameHist, frameHist, 0, 255, cv2.NORM_MINMAX)
# Reashape the histogram into a 1-D array (use `.reshape(-1)`)
frameHist = frameHist.reshape(-1)
# Show the histogram
#show_hist(frameHist)

# %%
sv = tracking_window_face

# %%
PATH = '/content/drive/MyDrive/Projet_Computer_Vision/Dataset/Test_C/'

# %%
tracking_window_face = sv

VideoCapture()
eval_js('create()')
# These mean: Stop the mean-shift algorithm iff we effectuated 10 iterations or the computed mean does not change by more than 1pt ~ 1.3px in both directions
term_crit = ( cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 1 )

# Take a capture from the video
byte = eval_js('capture()')
# Retrieves the width and height of the image
im_width, im_height = im.shape[1],im.shape[0] # To be used in the boundary constraints
# Transform the capture from base64 to an array
im = b64_to_bytes(byte)

tracking_window_hand = (0,0,im_width,im_height) # Define the initial tracking window for the hand. It spans the entire caption

# Initialise a counter, so the first image will be the image 0
cpt = -1

while True:
  byte = eval_js('capture()') # Take a capture
  im = b64_to_bytes(byte) # Transform the capture from base64 to an array

  # Transform the image into HSV
  frameHSV = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
  # Compute the standard not too bright not too dark mask
  mask = cv2.inRange(frameHSV, np.array((0., 64., 32.)), np.array((180., 200., 200.)))

  # Back project the histogramm on the hsv img. Use only channel 0 (Hue), range of [0,180] and scale of 1
  prob = cv2.calcBackProject([frameHSV], [0], frameHist, [0, 180], scale=1)

  # Apply the mask
  prob = prob & mask
  (x,y,w,h) = tracking_window_face # Area contains the face detection result
  # First look up for the face using cam shift starting from `tracking_window_face`
  # The first parameter is the back projection, the second parameter is the tracking window (this has been first computed in the beginning)
  bbox, tracking_window_face = cv2.CamShift(prob, tracking_window_face, term_crit) # Use new prob to do CamShift

  # Retrieve the rotated bounding rectangle
  pts = cv2.boxPoints(bbox).astype(np.int)

  # Find the centroid of image and better scale the bounding box
  # Scale the rotated bounding box 1.5x times  
  scaled_pts = scale_contour(pts, 1.5, 1.5)

  # Fill the rotated face bounding box with 0 in the prob map
  cv2.fillPoly(prob, [scaled_pts], 0)

  # Draw the bounding box around the face
  #cv2.polylines(prob, [pts], True, (255, 255 , 255), 2) # Draw a rectangle around the face
  #cv2.polylines(prob, [scaled_pts], True, (255, 255 , 0), 2)
  #cv2.polylines(im, [scaled_pts], True, (255, 255 , 0), 2) # Draw a rectangle around the face

  # Now look up for the hand using cam shift starting from `tracking_window_hand`

  bbox, tracking_window_hand = cv2.CamShift(prob, tracking_window_hand, term_crit)

  pts = cv2.boxPoints(bbox).astype(np.int) # Retrieve the rotated bounding rectangle

  # Find the centroid of image and better scale the bounding box
  # Scale the contour around the hand
  pts = scale_contour(pts, 1.75, 1.5)

  # Hand detected
  cropped_hand_bbox = crop_hand(pts, im_width, im_height)

  #cv2.polylines(prob, [pts], True, (255, 255 , 255), 2) # Draw a rectangle around the hand
  #cv2.polylines(im, [pts], True, (255, 255 , 255), 2)
  cv2.rectangle(im, cropped_hand_bbox[0], cropped_hand_bbox[1], (255, 0, 0), 2) # Draw a rectangle around the cropped hand

  # Transform the color image into gray image
  cropped_hand = cv2.cvtColor(im[cropped_hand_bbox[0][1]:cropped_hand_bbox[1][1], cropped_hand_bbox[0][0]:cropped_hand_bbox[1][0]], cv2.COLOR_BGR2GRAY)
  # We create two sizes of images: 32x32 and 224x224 (16x16 is not very good)
  cropped_hand = cv2.resize(cropped_hand, (32,32))
  
  cpt += 1

  # Once we have detected the hand, we store it as an image
  cv2.imwrite(PATH + 'C_' + str(cpt) + '.jpg', cropped_hand)

  ## Draw the bounding box around the hand
  #eval_js('showimg("{}")'.format(bytes_to_b64(prob))) # Show the prob image
  eval_js('showimg("{}")'.format(bytes_to_b64(im))) # Show the image
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-0d2752532f36> in <module>()
#      84   ## Draw the bounding box around the hand
#      85   #eval_js('showimg("{}")'.format(bytes_to_b64(prob))) # Show the prob image
# ---> 86   eval_js('showimg("{}")'.format(bytes_to_b64(im)))
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# **Prediction**
#
# After saving the image, we reload it and resize it to pass to our model. Then we predict the letter.

# %% [markdown]
# Remember that we used the Softmax activation function when creating our model. This activation function doesn’t compute the prediction, but rather a discrete probability distribution over the target classes.
# Now, we can finalize our work by actually finding out what our predicted classes are, by taking the argmax values (or “maximum argument”, index of the maximum value), with the function argmax().

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import os
import time

mypath="/content/drive/MyDrive/Projet_Computer_Vision/Dataset/Test_C"

# Create an array with all the images in '.jpg'
onlyfiles = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

t1 = time.time()
cpt = 0
for x in onlyfiles:
  imPath=mypath + '/' + x # The path to an image
  hand_image=Image.open(imPath) # Load saved image

  ####hand_image=np.reshape(hand_image,(1,1024)) # Uncomment when we use the MLP
  hand_image=np.reshape(hand_image,(-1,32,32,1)) # Uncomment when we use the CNN

  prediction = loaded_model.predict(hand_image) # Where hand_image is the probability image of your hand of size (1,1024)
  prediction = prediction.argmax() # prediction variable will be 0, 1 or 2 for A, B or C respectively
  predicted_letter = chr(ord('A') + prediction)

  # We show the images
  img=plt.imread(imPath)
  imgplot=plt.imshow(img)
  plt.show()
  
  print("I think the letter is a " + predicted_letter + " and the real one is: " + x[0])

  if (predicted_letter == x[0]):
    cpt += 1

print(" ")
t2 = time.time()
t_final = t2-t1
print("The execution time for", len(onlyfiles),"images is:", t_final)

print("The number of errors is:", len(onlyfiles)-cpt)
print("The accuracy is:", cpt/len(onlyfiles))
# Out:
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
# I think the letter is a C and the real one is: C
#
# The execution time for 100 images is: 49.05357122421265
# The number of errors is: 0
# The accuracy is: 1.0

# %% [markdown]
# **Conclusion**
#
# We observe that the CNN is more efficient than the MLP, but the CNN is slightly slower than the MLP. Indeed, the scores are:
# - For the MLP :
#   * For the letter A, the execution time for 100 images is **37.05** seconds and the accuracy is **0.49**.
#   * For the letter B, the execution time for 100 images is **35.66** seconds and the accuracy is **1.0**.
#   * For the letter C, the execution time for 100 images is **34.51** seconds and the accuracy is **0.8**.
#
# Notice that when we predict with a dataset with all the 3 letters suffled, the accuracy is roughly 0.8.
#
# - For the CNN :
#   * For the letter A, the execution time for 100 images is **34.76** seconds and the accuracy is **1.0**.
#   * For the letter B, the execution time for 100 images is **40.00** seconds and the accuracy is **1.0**.
#   * For the letter C, the execution time for 100 images is **49.05** seconds and the accuracy is **1.0**.
#
# Notice that when we predict with a dataset with all the 3 letters suffled, the accuracy is also 1.0.

# %% [markdown]
# **Visualizing Feature maps or Activation maps generated in a CNN**
#
# Feature maps are generated by applying Filters or Feature detectors to the input image or the feature map output of the prior layers. Feature map visualization will provide insight into the internal representations for specific input for each of the Convolutional layers in the model.
#
# Visualizing an inside story of how CNN learns to identify different features present in images provides a deeper insight into how the model works. It will also help to understand why the model might be failing to classify some of the images correctly and hence fine-tuning the model for better accuracy and precision.

# %%
from tensorflow.keras.preprocessing.image import img_to_array, load_img

img_path='/content/drive/MyDrive/Projet_Computer_Vision/Dataset/C_32/C_0_32.jpg'

# Define a new model, visualization_model that will take an image as the input. 
# The output of the model will be feature maps, which are an intermediate representation for all layers after the first layer. 
# This is based on the model we have used for training.
successive_outputs = [layer.output for layer in loaded_model.layers[1:]]

#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = loaded_model.input, outputs = successive_outputs)

# Load the input image for which we want to view the Feature map to understand which features were prominent to classify the image.
img = load_img(img_path, target_size=(32, 32))

# Convert the image to NumPy array
x = img_to_array(img)                         
x = np.reshape(x,(-1,32,32,1))

# Normalize the array by rescaling it
x /= 255.0

# Run the input image through the visualization model to obtain all intermediate representations for the input image.
successive_feature_maps = visualization_model.predict(x)

# Create the plot for all of the convolutional layers and the max pool layers but not for the fully connected layer. 
# For plotting the Feature maps, retrieve the layer name for each of the layers in the model.
layer_names = [layer.name for layer in loaded_model.layers]
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  print(feature_map.shape)
  if len(feature_map.shape) == 4:
    
    # Plot Feature maps for the conv / maxpool layers, not the fully-connected layers
   
    n_features = feature_map.shape[-1]  # number of features in the feature map
    size = feature_map.shape[ 1]  # feature map shape (1, size, size, n_features)
    
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    
    # Postprocess the feature to be visually plotable
    for i in range(n_features):
      x = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      # Tile each filter into a horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# (3, 16, 16, 32)
# (3, 16, 16, 64)
# (3, 8, 8, 64)
# (3, 8, 8, 64)
# (3, 4, 4, 64)
# (3, 4, 4, 64)
# (3, 4, 4, 128)
# (3, 2, 2, 128)
# (3, 2, 2, 128)
# (3, 128)
# (3, 64)
# (3, 3)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# We can see that all the hand is a very prominent features. Indeed, this is not a very complex image compared to a dog for example. But the resolution of the image is very small (32x32) so we cannot see properly what happened. It is better with the resolution of images 224x224 (see the Task 9). But it is interesting to see what happened in each CNN layer.
